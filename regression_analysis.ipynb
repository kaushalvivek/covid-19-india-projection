# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon, ttest_ind, normaltest, shapiro
from scipy.stats import pearsonr
import statsmodels.api as sm

# %%
df = pd.read_excel("consolidated.xlsx",index_col=0)
list_params = ["percent_asthma","TB cases per 100,000","Population Density (per sq. Mile)","Adults 55-64","65+",
              "Median Age","% High school graduate","HDI","Diabetes_Percentage","Percentage_Hypertension",
               "HIV_percentage","totaltestresults"]
df2 = df[list_params]

# %%
target = df['frac_deaths']
model = sm.OLS(target, df2).fit()
predictions = model.predict(df2)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            frac_deaths   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     25.67
# Date:                Mon, 04 May 2020   Prob (F-statistic):           8.31e-15
# Time:                        23:08:54   Log-Likelihood:                 150.47
# No. Observations:                  51   AIC:                            -276.9
# Df Residuals:                      39   BIC:                            -253.8
# Df Model:                          12
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# percent_asthma                        0.0017      0.002      0.773      0.444      -0.003       0.006
# TB cases per 100,000                 -0.0012      0.002     -0.638      0.527      -0.005       0.003
# Population Density (per sq. Mile) -1.349e-06   2.12e-06     -0.635      0.529   -5.65e-06    2.95e-06
# Adults 55-64                          0.1207      0.441      0.273      0.786      -0.772       1.013
# 65+                                  -0.5384      0.235     -2.295      0.027      -1.013      -0.064
# Median Age                            0.0049      0.003      1.751      0.088      -0.001       0.011
# % High school graduate               -0.0622      0.046     -1.363      0.181      -0.154       0.030
# HDI                                  -0.0109      0.017     -0.649      0.520      -0.045       0.023
# Diabetes_Percentage                   0.0036      0.003      1.122      0.269      -0.003       0.010
# Percentage_Hypertension              -0.1991      0.126     -1.583      0.122      -0.454       0.055
# HIV_percentage                        0.1708      0.375      0.456      0.651      -0.587       0.929
# totaltestresults                  -7.422e-08   5.37e-08     -1.382      0.175   -1.83e-07    3.44e-08
# ==============================================================================
# Omnibus:                        1.306   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.520   Jarque-Bera (JB):                1.246
# Skew:                           0.359   Prob(JB):                        0.536
# Kurtosis:                       2.732   Cond. No.                     1.21e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
target = df['cases_per_100K']
model = sm.OLS(target, df2).fit()
predictions = model.predict(df2)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         cases_per_100K   R-squared:                       0.582
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     4.521
# Date:                Mon, 04 May 2020   Prob (F-statistic):           0.000158
# Time:                        23:08:54   Log-Likelihood:                -334.09
# No. Observations:                  51   AIC:                             692.2
# Df Residuals:                      39   BIC:                             715.4
# Df Model:                          12
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# percent_asthma                      -22.0267     30.015     -0.734      0.467     -82.737      38.684
# TB cases per 100,000                -10.6072     24.566     -0.432      0.668     -60.297      39.082
# Population Density (per sq. Mile)     0.0262      0.028      0.922      0.362      -0.031       0.084
# Adults 55-64                       4261.3183   5902.948      0.722      0.475   -7678.521    1.62e+04
# 65+                               -7754.7525   3137.923     -2.471      0.018   -1.41e+04   -1407.704
# Median Age                           76.9212     37.641      2.044      0.048       0.786     153.057
# % High school graduate            -1410.5539    610.177     -2.312      0.026   -2644.753    -176.355
# HDI                                 -72.4679    224.555     -0.323      0.749    -526.673     381.737
# Diabetes_Percentage                  16.0153     43.087      0.372      0.712     -71.137     103.168
# Percentage_Hypertension           -2158.1825   1682.535     -1.283      0.207   -5561.431    1245.066
# HIV_percentage                     1831.9139   5012.318      0.365      0.717   -8306.457     1.2e+04
# totaltestresults                     -0.0012      0.001     -1.635      0.110      -0.003       0.000
# ==============================================================================
# Omnibus:                       41.145   Durbin-Watson:                   2.331
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              135.369
# Skew:                           2.206   Prob(JB):                     4.03e-30
# Kurtosis:                       9.651   Cond. No.                     1.21e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
